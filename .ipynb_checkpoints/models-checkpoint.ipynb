# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
df = pd.read_csv('data/laptop_df.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0   price manufacturer graphics_copressor  ram processor_brand  \
# 0           0  2287.0    Microsoft             NVIDIA    8           Intel
#
#    touchable  ips         ppi       cpu_name  memory       os
# 0          1    0  267.077872  Intel Core i7     256  Windows

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head(1)
# Out:
#     price manufacturer graphics_copressor  ram processor_brand  touchable  \
# 0  2287.0    Microsoft             NVIDIA    8           Intel          1
#
#    ips         ppi       cpu_name  memory       os
# 0    0  267.077872  Intel Core i7     256  Windows

# %%
X = df.drop(columns=['price'])
y = np.log(df['price'])

# %%
X
# Out:
#       Unnamed: 0 manufacturer graphics_copressor  ram processor_brand  \
# 0              0    Microsoft             NVIDIA    8           Intel
# 1              1    Microsoft             NVIDIA   16           Intel
# 2              2         Dell             NVIDIA   64           Intel
# 3              3         Dell             NVIDIA    8           Intel
# 4              4    Microsoft             NVIDIA   16           Intel
# ...          ...          ...                ...  ...             ...
# 1100        1257       Lenovo                AMD   16             AMD
# 1101        1258       Lenovo              Intel   20           Intel
# 1102        1259       Lenovo             NVIDIA   32           Intel
# 1103        1260       Lenovo             NVIDIA   32           Intel
# 1104        1261       Lenovo             NVIDIA   32           Intel
#
#       touchable  ips         ppi               cpu_name  memory       os
# 0             1    0  267.077872          Intel Core i7     256  Windows
# 1             1    0  240.370085          Intel Core i7     256  Windows
# 2             0    0  141.211998          Intel Core i9    2048  Windows
# 3             0    0  141.509717          Intel Core i7    1024  Windows
# 4             0    0  240.370085          Intel Core i7    1024  Windows
# ...         ...  ...         ...                    ...     ...      ...
# 1100          1    1  157.350512            AMD Ryzen 7    1024  Windows
# 1101          0    0  141.211998  Other Intel Processor    1024  Windows
# 1102          0    0  188.679623          Intel Core i9    1024  Windows
# 1103          1    1  157.350512          Intel Core i7    1024  Windows
# 1104          0    1  157.350512          Intel Core i7    1024  Windows
#
# [1105 rows x 11 columns]

# %%
X.drop(columns=['Unnamed: 0'], inplace=True)

# %%
X
# Out:
#      manufacturer graphics_copressor  ram processor_brand  touchable  ips  \
# 0       Microsoft             NVIDIA    8           Intel          1    0
# 1       Microsoft             NVIDIA   16           Intel          1    0
# 2            Dell             NVIDIA   64           Intel          0    0
# 3            Dell             NVIDIA    8           Intel          0    0
# 4       Microsoft             NVIDIA   16           Intel          0    0
# ...           ...                ...  ...             ...        ...  ...
# 1100       Lenovo                AMD   16             AMD          1    1
# 1101       Lenovo              Intel   20           Intel          0    0
# 1102       Lenovo             NVIDIA   32           Intel          0    0
# 1103       Lenovo             NVIDIA   32           Intel          1    1
# 1104       Lenovo             NVIDIA   32           Intel          0    1
#
#              ppi               cpu_name  memory       os
# 0     267.077872          Intel Core i7     256  Windows
# 1     240.370085          Intel Core i7     256  Windows
# 2     141.211998          Intel Core i9    2048  Windows
# 3     141.509717          Intel Core i7    1024  Windows
# 4     240.370085          Intel Core i7    1024  Windows
# ...          ...                    ...     ...      ...
# 1100  157.350512            AMD Ryzen 7    1024  Windows
# 1101  141.211998  Other Intel Processor    1024  Windows
# 1102  188.679623          Intel Core i9    1024  Windows
# 1103  157.350512          Intel Core i7    1024  Windows
# 1104  157.350512          Intel Core i7    1024  Windows
#
# [1105 rows x 10 columns]

# %%
y
# Out:
# 0       7.734996
# 1       8.006034
# 2       8.004700
# 3       7.600402
# 4       8.006034
#           ...
# 1100    7.207119
# 1101    6.378426
# 1102    8.582981
# 1103    7.521859
# 1104    7.414573
# Name: price, Length: 1105, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# %% [markdown]
# ## Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0,1,3,7,9])
], remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print('R2 score ',r2_score(y_test, y_pred))
print('MAE ', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score  0.8575468283787182
# MAE  0.19262674803608282

# %%
np.exp(0.19)
# Out:
# 1.2092495976572515

# %% [markdown]
# ## Ridge

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0,1,3,7,9])
], remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print('R2 score ',r2_score(y_test, y_pred))
print('MAE ', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score  0.8520749158084466
# MAE  0.1956002645708391
